# %%
import math
import matplotlib.pyplot as plt
import numpy as np

pontos = 20
step = math.pi / (2*pontos)
t = np.arange(0, pontos*step, step)
pwm = [math.sin(i) for i in t]
plt.plot(t,pwm,'r')
display({h for h in pwm})
# Out:
# {0.0,
#  0.07845909572784494,
#  0.15643446504023087,
#  0.2334453638559054,
#  0.3090169943749474,
#  0.3826834323650898,
#  0.45399049973954675,
#  0.5224985647159488,
#  0.5877852522924731,
#  0.6494480483301837,
#  0.7071067811865476,
#  0.7604059656000309,
#  0.8090169943749475,
#  0.8526401643540922,
#  0.8910065241883678,
#  0.9238795325112867,
#  0.9510565162951535,
#  0.9723699203976766,
#  0.9876883405951378,
#  0.996917333733128}
